# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_spss(r"D:\Users\W10\Documents\GitHub\1ECO35_2022_2\data\data_administrativa.sav" )

# %%
import savReaderWriter as sav  


with sav.SavHeaderReader( r"D:\Users\W10\Documents\GitHub\1ECO35_2022_2\data\data_administrativa.sav", ioUtf8=True) as header:
    data_general = header.all()
    etiqueta_value = data_general.valueLabels  # get labels from varaibles varaibles's values 
    etiqueta_var = data_general.varLabels # get labels from varaibles

# %%
etiqueta_value
# Out:
# {'DOMINIO': {1.0: 'Costa Norte',
#   2.0: 'Costa Centro',
#   3.0: 'Costa Sur',
#   4.0: 'Sierra Norte',
#   5.0: 'Sierra Centro',
#   6.0: 'Sierra Sur',
#   7.0: 'Selva',
#   8.0: 'Lima Metropolitana'},
#  'ESTRATO': {1.0: ' De 500 000 a más habitantes',
#   2.0: ' De 100 000 a 499 999 habitantes',
#   3.0: ' De 50 000 a 99 999 habitantes',
#   4.0: ' De 20 000 a 49 999 habitantes',
#   5.0: 'De 2 000 a 19 999 habitantes',
#   6.0: ' De 500 a 1 999 habitantes',
#   7.0: ' Área de Empadronamiento Rural (AER) Compuesto',
#   8.0: ' Área de Empadronamiento Rural (AER) Simple'},
#  'P203': {0.0: 'Panel',
#   1.0: 'Jefe/Jefa',
#   2.0: 'Esposo(a)/compañero(a)',
#   3.0: 'Hijo(a)/Hijastro(a)',
#   4.0: 'Yerno/Nuera',
#   5.0: 'Nieto(a)',
#   6.0: 'Padres/Suegros',
#   7.0: 'Otros parientes',
#   8.0: 'Trabajador Hogar',
#   9.0: 'Pensionista',
#   10.0: 'Otros no parientes',
#   11.0: 'Hermano(a)'},
#  'P203B': {1.0: 'Jefe/jefa de hogar',
#   2.0: 'Esposa(o)',
#   3.0: 'Hijo(a)',
# ...

# %%
etiqueta_var
# Out:
# {'year': '',
#  'MES': '',
#  'CONGLOME': '',
#  'VIVIENDA': '',
#  'HOGAR': '',
#  'CODPERSO': '',
#  'UBIGEO': '',
#  'DOMINIO': 'Dominio geográfico',
#  'ESTRATO': 'Estrato geográfico',
#  'P201P': '',
#  'P203': '¿Cuál es la relación de parentesco con el jefe(a) del hogar',
#  'P203A': '',
#  'P203B': 'Relación de parentesco con el jefe(a) del núcleo familiar',
#  'P204': '¿Es miembro del hogar?',
#  'P205': '¿Se encuentra ausente del hogar 30 días o más?',
#  'P206': '¿Está presente en el hogar 30 días o más?',
#  'P207': 'Sexo',
#  'P208A': '',
#  'P208B': '',
#  'P209': '¿Cuál es su estado civil o conyugal?'}

# %%
data[data.loc[:, ['CONGLOME','VIVIENDA','HOGAR','CODPERSO']].duplicated()]
# Out:
#        year MES CONGLOME VIVIENDA HOGAR CODPERSO  UBIGEO        DOMINIO  \
# 2632   2020  01   006571      174    11       02  100402  Sierra Centro
# 2724   2019  10   005278      048    11       04  021701  Sierra Centro
# 2773   2020  12   005190      037    11       01  021801   Costa Centro
# 3135   2019  12   006886      168    11       02  120114  Sierra Centro
# 3663   2019  02   008611      048    11       04  190113  Sierra Centro
# ...     ...  ..      ...      ...   ...      ...     ...            ...
# 84940  2019  12   008253      047    11       01  160113          Selva
# 84945  2019  06   007982      008    11       02  150202   Costa Centro
# 84975  2020  09   007221      043    11       03  130901   Sierra Norte
# 84982  2019  07   008806      114    11       04  200701    Costa Norte
# 85000  2020  02   009338      017    11       03  230108      Costa Sur
#
#                                               ESTRATO              P201P  \
# ...

# %%
data_2019 = data.loc[data.year == "2019", : ] 
data_2019
# Out:
#        year MES CONGLOME VIVIENDA HOGAR CODPERSO  UBIGEO             DOMINIO  \
# 3      2019  10   010614      043    11       07  130901        Sierra Norte
# 5      2019  03   008010      059    11       03  150801        Costa Centro
# 6      2019  07   009737      016    11       01  250302               Selva
# 11     2019  07   008002      075    11       03  150204        Costa Centro
# 12     2019  08   010034      072    11       01  040109          Sierra Sur
# ...     ...  ..      ...      ...   ...      ...     ...                 ...
# 85026  2019  01   008317      073    11       07  160301               Selva
# 85028  2019  07   007556      038    11       04  150117  Lima Metropolitana
# 85029  2019  08   005664      018    11       03  040203           Costa Sur
# 85031  2019  04   008226      084    13       02  160112               Selva
# 85032  2019  05   008965      060    11       03  210101          Sierra Sur
#
# ...

# %%
data_2020 = data.loc[data.year == "2020", : ] 
data_2020
# Out:
#        year MES CONGLOME VIVIENDA HOGAR CODPERSO  UBIGEO             DOMINIO  \
# 0      2020  06   010108      136    11       02  100111       Sierra Centro
# 1      2020  06   020257      093    11       04  250107               Selva
# 2      2020  06   015537      065    11       04  040126          Sierra Sur
# 4      2020  06   009390      096    11       04  230110           Costa Sur
# 7      2020  06   017794      111    11       01  150122  Lima Metropolitana
# ...     ...  ..      ...      ...   ...      ...     ...                 ...
# 85025  2020  06   006153      118    11       02  070101  Lima Metropolitana
# 85027  2020  06   018585      006    11       03  160101               Selva
# 85030  2020  12   007337      004    11       01  140105         Costa Norte
# 85033  2020  05   010311      022    11       02  200501         Costa Norte
# 85034  2020  11   018778      155    11       06  160404               Selva
#
# ...
