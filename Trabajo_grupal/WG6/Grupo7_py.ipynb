# %%
import os                  # for usernanme y set direcotrio
import pandas as pd
import numpy as np
import weightedcalcs as wc # ponderador o factor de expansion
from tqdm import tqdm      # controlar el tiempo en un loop ()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Salario por hora del trabajador dependiente (Python y R)
# ---

# %% [markdown]
# #### 2019

# %%
# Cargando bases de datos 2019
enaho01 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2019/687-Modulo01/687-Modulo01/enaho01-2019-100.dta")
enaho34 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2019/687-Modulo34/687-Modulo34/sumaria-2019.dta")

print(enaho01.shape)
print(enaho34.shape)
# Out:
# (43868, 323)
# (34565, 158)

# %%
# identificador por hogar: conglome, vivienda, hogar

merge_base_2019 = pd.merge(enaho01, enaho34,
                       on = ["conglome", "vivienda", "hogar"],
                       how = "left",
                       validate = "m:1",
                       suffixes=('', '_y'))

# %%
## drop variables que tenrminan en _y
index_columns = np.where( merge_base_2019.columns.str.contains('_y$', regex=True))[0]
merge_base_2019.drop(merge_base_2019.columns[index_columns], axis = 1, inplace = True)

# %% [markdown]
# #### 2020

# %%
# Cargando bases de datos 2020
enaho01 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2020/737-Modulo01/737-Modulo01/enaho01-2020-100.dta")
enaho34 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2020/737-Modulo34/737-Modulo34/sumaria-2020.dta")

# %%
# identificador por hogar: conglome, vivienda, hogar

merge_base_2020 = pd.merge(enaho01, enaho34,
                       on = ["conglome", "vivienda", "hogar"],
                       how = "left",
                       validate = "m:1",
                       suffixes=('', '_y'))

# %%
## drop variables que tenrminan en _y
index_columns = np.where( merge_base_2020.columns.str.contains('_y$', regex=True))[0]
merge_base_2020.drop(merge_base_2020.columns[index_columns], axis = 1, inplace = True)

# %% [markdown]
# #### juntando bases 2019 y 2020

# %%
# Juntando bases del 2019 y 2020
base_2019_2020 = merge_base_2019.append(merge_base_2020, ignore_index= True)  # ignore_index=True, para evitar conflictos de index
base_2019_2020
# Out:
#         aÑo mes nconglome conglome vivienda hogar  ubigeo       dominio  \
# 0      2019  10    007060   005001      007    11  010101  sierra norte
# 1      2019  10    007060   005001      017    11  010101  sierra norte
# 2      2019  10    007060   005001      028    11  010101  sierra norte
# 3      2019  10    007060   005001      040    11  010101  sierra norte
# 4      2019  10    007060   005001      050    11  010101  sierra norte
# ...     ...  ..       ...      ...      ...   ...     ...           ...
# 97286  2020  12    015122   020305      052    11  250301         selva
# 97287  2020  12    015122   020305      073    11  250301         selva
# 97288  2020  12    015122   020305      094    11  250301         selva
# 97289  2020  12    015122   020305      116    11  250301         selva
# 97290  2020  12    015122   020305      137    11  250301         selva
#
#                               estrato  periodo  ... ingtpu071  ingtpu08  \
# 0       de 20 000 a 49 999 habitantes        1  ...       NaN       NaN
# 1       de 20 000 a 49 999 habitantes        1  ...       NaN       NaN
# 2       de 20 000 a 49 999 habitantes        1  ...       NaN       NaN
# 3       de 20 000 a 49 999 habitantes        1  ...       NaN       NaN
# 4       de 20 000 a 49 999 habitantes        1  ...       NaN       NaN
# ...                               ...      ...  ...       ...       ...
# 97286   de 20 000 a 49 999 habitantes        2  ...       0.0       0.0
# 97287   de 20 000 a 49 999 habitantes        2  ...       0.0       0.0
# 97288   de 20 000 a 49 999 habitantes        2  ...       NaN       NaN
# 97289   de 20 000 a 49 999 habitantes        2  ...       0.0       0.0
# 97290   de 20 000 a 49 999 habitantes        2  ...       0.0       0.0
#
#       ingtpu081 ingtpu09 ingtpu091     inghog1d1     inghog2d1 lineav_rpl  \
# 0           NaN      NaN       NaN           NaN           NaN        NaN
# 1           NaN      NaN       NaN           NaN           NaN        NaN
# 2           NaN      NaN       NaN           NaN           NaN        NaN
# 3           NaN      NaN       NaN           NaN           NaN        NaN
# 4           NaN      NaN       NaN           NaN           NaN        NaN
# ...         ...      ...       ...           ...           ...        ...
# 97286       0.0      0.0       0.0  11442.000000  11442.000000      657.0
# 97287       0.0      0.0       0.0  12083.000000  12083.000000      657.0
# 97288       NaN      NaN       NaN           NaN           NaN        NaN
# 97289       0.0      0.0       0.0  21009.353516  21009.353516      657.0
# 97290       0.0    762.0     762.0  19060.650391  19060.650391      657.0
#
#            lineav             pobrezav
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN                  NaN
# 4             NaN                  NaN
# ...           ...                  ...
# 97286  642.814026        no vulnerable
# 97287  641.782898        no vulnerable
# 97288         NaN                  NaN
# 97289  643.160034  vulnerable no pobre
# 97290  639.233521  vulnerable no pobre
#
# [97291 rows x 500 columns]

# %%
# extrae 2 primeros digitos

base_2019_2020['ubigeo_dep'] = base_2019_2020['ubigeo'].str[:2]

# %%
# convirtiendo variables a int para futuro merge

base_2019_2020[['aÑo', 'ubigeo_dep']] = base_2019_2020[['aÑo', 'ubigeo_dep']].astype(int)

# %% [markdown]
# #### Deflactor temporal

# %%
### Deflactor temporal
deflactores_base2020_new = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2020/737-Modulo34/737-Modulo34/ConstVarGasto-Metodologia actualizada/Gasto2020/Bases/deflactores_base2020_new.dta")
deflactores_base2020_new = deflactores_base2020_new[ ["dpto", "aniorec", "i00"] ]
deflactores_base2020_new.head()
# Out:
#    dpto  aniorec       i00
# 0   1.0   2001.0  0.607886
# 1   2.0   2001.0  0.565700
# 2   3.0   2001.0  0.636805
# 3   4.0   2001.0  0.532813
# 4   5.0   2001.0  0.571589

# %%
# identificador por hogar: conglome, vivienda, hogar

base_2019_2020 = pd.merge(base_2019_2020, deflactores_base2020_new,
                      left_on = ["ubigeo_dep", "aÑo"],
                      right_on = ["dpto", "aniorec"],
                      how = "left",
                      validate = "m:1")

# %%
# dividiento variables de ingreso y gasto por mieperho, 12, ld e i00

base_2019_2020['ingreso_deflact'] = base_2019_2020['inghog1d'] / (12 * base_2019_2020['mieperho'] * base_2019_2020['ld'] * base_2019_2020['i00'])
base_2019_2020['gasto_deflact']   = base_2019_2020['gashog2d'] / (12 * base_2019_2020['mieperho'] * base_2019_2020['ld'] * base_2019_2020['i00'])

# %%
# ordenando datos para poder compararlos con los resultados de R

base_2019_2020 = base_2019_2020.sort_values(by=['conglome', 'vivienda', 'hogar' ], axis=0, ascending=True, ignore_index=True)

base_2019_2020
# Out:
#         aÑo mes nconglome conglome vivienda hogar  ubigeo       dominio  \
# 0      2019  10    007060   005001      007    11  010101  sierra norte
# 1      2019  10    007060   005001      017    11  010101  sierra norte
# 2      2019  10    007060   005001      028    11  010101  sierra norte
# 3      2019  10    007060   005001      040    11  010101  sierra norte
# 4      2019  10    007060   005001      050    11  010101  sierra norte
# ...     ...  ..       ...      ...      ...   ...     ...           ...
# 97286  2020  11    049322   020353      036    11  250103         selva
# 97287  2020  11    049322   020353      043    11  250103         selva
# 97288  2020  11    049322   020353      049    11  250103         selva
# 97289  2020  11    049322   020353      055    11  250103         selva
# 97290  2020  11    049322   020353      062    11  250103         selva
#
#                               estrato  periodo  ...     inghog2d1  lineav_rpl  \
# 0       de 20 000 a 49 999 habitantes        1  ...           NaN         NaN
# 1       de 20 000 a 49 999 habitantes        1  ...           NaN         NaN
# 2       de 20 000 a 49 999 habitantes        1  ...           NaN         NaN
# 3       de 20 000 a 49 999 habitantes        1  ...           NaN         NaN
# 4       de 20 000 a 49 999 habitantes        1  ...           NaN         NaN
# ...                               ...      ...  ...           ...         ...
# 97286       de 500 a 1 999 habitantes        3  ...           NaN         NaN
# 97287       de 500 a 1 999 habitantes        3  ...           NaN         NaN
# 97288       de 500 a 1 999 habitantes        3  ...  18743.167969       657.0
# 97289       de 500 a 1 999 habitantes        3  ...  49633.332031       657.0
# 97290       de 500 a 1 999 habitantes        3  ...  31360.960938       657.0
#
#            lineav             pobrezav ubigeo_dep  dpto aniorec       i00  \
# 0             NaN                  NaN          1   1.0  2019.0  0.982802
# 1             NaN                  NaN          1   1.0  2019.0  0.982802
# 2             NaN                  NaN          1   1.0  2019.0  0.982802
# 3             NaN                  NaN          1   1.0  2019.0  0.982802
# 4             NaN                  NaN          1   1.0  2019.0  0.982802
# ...           ...                  ...        ...   ...     ...       ...
# 97286         NaN                  NaN         25  25.0  2020.0  1.000000
# 97287         NaN                  NaN         25  25.0  2020.0  1.000000
# 97288  661.185608        no vulnerable         25  25.0  2020.0  1.000000
# 97289  663.352417  vulnerable no pobre         25  25.0  2020.0  1.000000
# 97290  663.531189  vulnerable no pobre         25  25.0  2020.0  1.000000
#
#       ingreso_deflact gasto_deflact
# 0          942.402727    818.567861
# 1          512.260548    421.077798
# 2                 NaN           NaN
# 3          802.508596    508.609816
# 4         1473.884077   1121.111288
# ...               ...           ...
# 97286             NaN           NaN
# 97287             NaN           NaN
# 97288     1636.985232   1311.325967
# 97289      558.539151    494.406453
# 97290      467.620048    494.151377
#
# [97291 rows x 506 columns]

# %% [markdown]
# ## 2. Salario por hora del trabajador dependiente (Python y R)
# ---

# %%
# Cargando modulo 05
enaho05 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2020/737-Modulo05/737-Modulo05/enaho01a-2020-500.dta")
enaho05 = enaho05[ ["i524e1", "i538e1", "i513t", "i518"] ]

# %%
# reemplazando NA por ceros
enaho05 = enaho05.fillna(0)
enaho05
# Out:
#         i524e1  i538e1  i513t  i518
# 0          0.0     0.0   70.0   0.0
# 1          0.0     0.0   70.0   0.0
# 2          0.0     0.0   84.0   0.0
# 3       2433.0     0.0   12.0  70.0
# 4          0.0     0.0    0.0   0.0
# ...        ...     ...    ...   ...
# 91310  10761.0     0.0   53.0   0.0
# 91311  14202.0     0.0   48.0   0.0
# 91312      0.0     0.0    0.0   0.0
# 91313   7680.0     0.0   34.0   0.0
# 91314   7680.0     0.0   70.0   0.0
#
# [91315 rows x 4 columns]

# %%
# generando variables necesarias
enaho05['ingreso'] = enaho05['i524e1'] + enaho05['i538e1']
enaho05['horas']   = enaho05['i513t'] + enaho05['i518']

# reemplazando NA por 0
enaho05['ingreso'] = enaho05['ingreso'].replace([''], 0)
enaho05['horas'] = enaho05['horas'].replace([''], 0)

# salario por hora
enaho05['sal_hora_depend'] = enaho05['ingreso'] / (enaho05['horas'] * 52)

# Si un salario por hora resulta 0, convertir a missing.
enaho05['sal_hora_depend'] = enaho05['sal_hora_depend'].replace([0], np.nan)

# visualizando variable calculada
enaho05[['sal_hora_depend']]
# Out:
#        sal_hora_depend
# 0             0.058909
# 1             0.062500
# 2             0.064103
# 3             0.069005
# 4             0.070251
# ...                ...
# 91310              NaN
# 91311              NaN
# 91312              NaN
# 91313              NaN
# 91314              NaN
#
# [91315 rows x 1 columns]

# %% [markdown]
# ## 3. Groupby (Python y R)
# ---

# %%
enaho02 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2020/737-Modulo02/737-Modulo02/enaho01-2020-200.dta")
enaho34 = pd.read_stata("C:/Users/Jose Pastor/Documents/datos_documents/enaho/2020/737-Modulo34/737-Modulo34/sumaria-2020.dta")

# %%
# identificando hogares con algun miembro mayor a 65 años
enaho02_1 = enaho02.groupby( [ "conglome", "vivienda", "hogar" ],
                            as_index = False ).agg( edad_max = ( 'p208a', max ))

enaho02_1
# Out:
#       conglome vivienda hogar  edad_max
# 0       005002      011    11      66.0
# 1       005002      023    11      62.0
# 2       005002      049    11      74.0
# 3       005002      073    11      60.0
# 4       005002      097    11      80.0
# ...        ...      ...   ...       ...
# 34485   020353      023    11      42.0
# 34486   020353      030    11      32.0
# 34487   020353      049    11      59.0
# 34488   020353      055    11      47.0
# 34489   020353      062    11      31.0
#
# [34490 rows x 4 columns]

# %%
# inner merge
base_final_2  = pd.merge(enaho02_1, enaho34,
                       on = ["conglome", "vivienda", "hogar"],
                       how = "left",
                       validate = "m:1")

# %%
# Generamos variable "pobre" mediante comparación entre gasto y linea de pobreza

base_final_2['gasto_month'] = base_final_2['gashog2d'] / (12*base_final_2['mieperho'])
base_final_2["pobre"] = np.where(base_final_2["gasto_month"] < base_final_2["linea"], "pobre", "no pobre")

# %%
base_final_2
# Out:
#       conglome vivienda hogar  edad_max   aÑo mes  ubigeo       dominio  \
# 0       005002      011    11      66.0  2020  03  010101  sierra norte
# 1       005002      023    11      62.0  2020  03  010101  sierra norte
# 2       005002      049    11      74.0  2020  03  010101  sierra norte
# 3       005002      073    11      60.0  2020  03  010101  sierra norte
# 4       005002      097    11      80.0  2020  03  010101  sierra norte
# ...        ...      ...   ...       ...   ...  ..     ...           ...
# 34485   020353      023    11      42.0  2020  11  250103         selva
# 34486   020353      030    11      32.0  2020  11  250103         selva
# 34487   020353      049    11      59.0  2020  11  250103         selva
# 34488   020353      055    11      47.0  2020  11  250103         selva
# 34489   020353      062    11      31.0  2020  11  250103         selva
#
#                              estrato  mieperho  ...  \
# 0      de 20,000 a 49,999 habitantes         4  ...
# 1      de 20,000 a 49,999 habitantes         1  ...
# 2      de 20,000 a 49,999 habitantes         4  ...
# 3      de 20,000 a 49,999 habitantes         2  ...
# 4      de 20,000 a 49,999 habitantes         1  ...
# ...                              ...       ...  ...
# 34485      de 500 a 1,999 habitantes         4  ...
# 34486      de 500 a 1,999 habitantes         3  ...
# 34487      de 500 a 1,999 habitantes         1  ...
# 34488      de 500 a 1,999 habitantes         8  ...
# 34489      de 500 a 1,999 habitantes         6  ...
#
#                                         tipocuestionario  tipoentrevista  \
# 0      cuestionario completo - antes de la emergencia...      presencial
# 1      cuestionario completo - antes de la emergencia...      presencial
# 2      cuestionario completo - antes de la emergencia...      presencial
# 3      cuestionario completo - antes de la emergencia...      presencial
# 4      cuestionario completo - antes de la emergencia...      presencial
# ...                                                  ...             ...
# 34485  cuestionario completo - durante la emergencia ...      presencial
# 34486  cuestionario completo - durante la emergencia ...      presencial
# 34487  cuestionario completo - durante la emergencia ...      presencial
# 34488  cuestionario completo - durante la emergencia ...      presencial
# 34489  cuestionario completo - durante la emergencia ...      presencial
#
#         factor07  nconglome  sub_conglome  lineav_rpl      lineav  \
# 0      57.675755     007061            00         657  553.702698
# 1      57.675755     007061            00         657  558.874207
# 2      57.675755     007061            00         657  551.961121
# 3      57.675755     007061            00         657  556.134399
# 4      57.675755     007061            00         657  562.409973
# ...          ...        ...           ...         ...         ...
# 34485  59.551132     049322            00         657  662.498047
# 34486  59.551132     049322            00         657  663.237122
# 34487  59.551132     049322            00         657  661.185608
# 34488  59.551132     049322            00         657  663.352417
# 34489  59.551132     049322            00         657  663.531189
#
#                   pobrezav  gasto_month     pobre
# 0            no vulnerable   647.939006  no pobre
# 1            no vulnerable  1993.775391  no pobre
# 2            no vulnerable  2173.834961  no pobre
# 3            no vulnerable  1173.763509  no pobre
# 4      vulnerable no pobre   328.488627  no pobre
# ...                    ...          ...       ...
# 34485        no vulnerable   816.233805  no pobre
# 34486        no vulnerable   696.493110  no pobre
# 34487        no vulnerable  1251.202637  no pobre
# 34488  vulnerable no pobre   471.738281  no pobre
# 34489  vulnerable no pobre   471.494900  no pobre
#
# [34490 rows x 182 columns]

# %% [markdown]
# #### Dummy mas de 65 años y pobre

# %%
# La estrategia es generara dummies tanto para pobreza y mayor a 65 años
# Luego se sumaran las dummies y aquellas que resulten 2 es porque cumple la condicion.
# Finalmente, se convertira el 2 en 1 para tener una dummy que cumpla con las condiciones.

base_final_2["dummy_pobre"]   = np.where(base_final_2["pobre"] == 'pobre', 1, 0)
base_final_2["dummy_mayor65"] = np.where(base_final_2["edad_max"] > 65, 1, 0)

# sumando dummies
base_final_2['dummy_suma'] = base_final_2["dummy_pobre"] + base_final_2["dummy_mayor65"]

# reemplazando 2 por 1
base_final_2['dummy_pobre_mayor65'] = np.where(base_final_2['dummy_suma'] == 2, 1, 0)

# %%
base_final_2
# Out:
#       conglome vivienda hogar  edad_max   aÑo mes  ubigeo       dominio  \
# 0       005002      011    11      66.0  2020  03  010101  sierra norte
# 1       005002      023    11      62.0  2020  03  010101  sierra norte
# 2       005002      049    11      74.0  2020  03  010101  sierra norte
# 3       005002      073    11      60.0  2020  03  010101  sierra norte
# 4       005002      097    11      80.0  2020  03  010101  sierra norte
# ...        ...      ...   ...       ...   ...  ..     ...           ...
# 34485   020353      023    11      42.0  2020  11  250103         selva
# 34486   020353      030    11      32.0  2020  11  250103         selva
# 34487   020353      049    11      59.0  2020  11  250103         selva
# 34488   020353      055    11      47.0  2020  11  250103         selva
# 34489   020353      062    11      31.0  2020  11  250103         selva
#
#                              estrato  mieperho  ...  sub_conglome  lineav_rpl  \
# 0      de 20,000 a 49,999 habitantes         4  ...            00         657
# 1      de 20,000 a 49,999 habitantes         1  ...            00         657
# 2      de 20,000 a 49,999 habitantes         4  ...            00         657
# 3      de 20,000 a 49,999 habitantes         2  ...            00         657
# 4      de 20,000 a 49,999 habitantes         1  ...            00         657
# ...                              ...       ...  ...           ...         ...
# 34485      de 500 a 1,999 habitantes         4  ...            00         657
# 34486      de 500 a 1,999 habitantes         3  ...            00         657
# 34487      de 500 a 1,999 habitantes         1  ...            00         657
# 34488      de 500 a 1,999 habitantes         8  ...            00         657
# 34489      de 500 a 1,999 habitantes         6  ...            00         657
#
#            lineav             pobrezav  gasto_month     pobre  dummy_pobre  \
# 0      553.702698        no vulnerable   647.939006  no pobre            0
# 1      558.874207        no vulnerable  1993.775391  no pobre            0
# 2      551.961121        no vulnerable  2173.834961  no pobre            0
# 3      556.134399        no vulnerable  1173.763509  no pobre            0
# 4      562.409973  vulnerable no pobre   328.488627  no pobre            0
# ...           ...                  ...          ...       ...          ...
# 34485  662.498047        no vulnerable   816.233805  no pobre            0
# 34486  663.237122        no vulnerable   696.493110  no pobre            0
# 34487  661.185608        no vulnerable  1251.202637  no pobre            0
# 34488  663.352417  vulnerable no pobre   471.738281  no pobre            0
# 34489  663.531189  vulnerable no pobre   471.494900  no pobre            0
#
#        dummy_mayor65  dummy_suma  dummy_pobre_mayor65
# 0                  1           1                    0
# 1                  0           0                    0
# 2                  1           1                    0
# 3                  0           0                    0
# 4                  1           1                    0
# ...              ...         ...                  ...
# 34485              0           0                    0
# 34486              0           0                    0
# 34487              0           0                    0
# 34488              0           0                    0
# 34489              0           0                    0
#
# [34490 rows x 186 columns]
